# %% [markdown]
# <a href="https://colab.research.google.com/github/VamsiReddy-hub/LMS_ASSIGNMENTS/blob/main/7_02_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Converting text to Features

# %%
Text = "Iam learning NLP"

# %%
import pandas as pd
pd.get_dummies(Text.split())
# Out:
#        I    NLP     am  learning
# 0   True  False  False     False
# 1  False  False   True     False
# 2  False  False  False      True
# 3  False   True  False     False

# %%
text = ["i love NLP i will learn NLP in 2months"]

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
vectorizer.fit(text)
vector = vectorizer.transform(text)

# %%
print(vectorizer.vocabulary_)
print(vector.toarray())
# Out:
# {'love': 3, 'nlp': 4, 'will': 5, 'learn': 2, 'in': 1, '2months': 0}
# [[1 1 1 1 2 1]]

# %%
print(vector)
# Out:
#   (0, 0)	1
#   (0, 1)	1
#   (0, 2)	1
#   (0, 3)	1
#   (0, 4)	2
#   (0, 5)	1

# %%
df=pd.DataFrame(data=vector.toarray(),columns=vectorizer.get_feature_names_out())
df
# Out:
#    2months  in  learn  love  nlp  will
# 0        1   1      1     1    2     1

# %%
text = 'I am learning Nlp'

# %%
import nltk
nltk.download('punkt_tab')
# !pip install textbolb
from textblob import TextBlob
TextBlob(text).ngrams(1)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ERROR: Could not find a version that satisfies the requirement textbolb (from versions: none)
# ERROR: No matching distribution found for textbolb
# [WordList(['I']), WordList(['am']), WordList(['learning']), WordList(['Nlp'])]

# %%
TextBlob(text).ngrams(2)
# Out:
# [WordList(['I', 'am']),
#  WordList(['am', 'learning']),
#  WordList(['learning', 'Nlp'])]

# %%
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import pickle
from sklearn.linear_model import LogisticRegressionCV
import re
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('covid_fake.csv')

# %%
df.head()
# Out:
#                                                title  ... label
# 0  Due to the recent outbreak for the Coronavirus...  ...  Fake
# 1                                                NaN  ...  Fake
# 2                                                NaN  ...  Fake
# 3                                                NaN  ...  Fake
# 4                                                NaN  ...  Fake
#
# [5 rows x 4 columns]

# %%
df.shape
# Out:
# (1164, 4)

# %%
df['label'].value_counts()
# Out:
# label
# TRUE    584
# Fake    345
# fake    230
# Name: count, dtype: int64

# %%
df.loc[5:15]
# Out:
#                                                 title  ... label
# 5   CORONA UNMASKED: Chinese Intelligence Officer ...  ...   NaN
# 6                                                 NaN  ...  Fake
# 7                                                 NaN  ...  Fake
# 8                                                 NaN  ...  Fake
# 9   Basic protective measures against the new coro...  ...  TRUE
# 10                                                NaN  ...  Fake
# 11                                                NaN  ...  Fake
# 12                                                NaN  ...  Fake
# 13                                                NaN  ...  Fake
# 14  Exposing yourself to the sun or to temperature...  ...  TRUE
# 15  You can recover from the coronavirus disease (...  ...   NaN
#
# [11 rows x 4 columns]
