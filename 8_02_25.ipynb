# %% [markdown]
# <a href="https://colab.research.google.com/github/VamsiReddy-hub/LMS_ASSIGNMENTS/blob/main/8_02_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Converting text to Features

# %%
Text = "Iam learning NLP"

# %%
import pandas as pd
pd.get_dummies(Text.split())
# Out:
#      Iam    NLP  learning
# 0   True  False     False
# 1  False  False      True
# 2  False   True     False

# %%
text = ["i love NLP i will learn NLP in 2months"]

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
vectorizer.fit(text)
vector = vectorizer.transform(text)

# %%
print(vectorizer.vocabulary_)
print(vector.toarray())
# Out:
# {'love': 3, 'nlp': 4, 'will': 5, 'learn': 2, 'in': 1, '2months': 0}
# [[1 1 1 1 2 1]]

# %%
print(vector)
# Out:
#   (0, 0)	1
#   (0, 1)	1
#   (0, 2)	1
#   (0, 3)	1
#   (0, 4)	2
#   (0, 5)	1

# %%
df=pd.DataFrame(data=vector.toarray(),columns=vectorizer.get_feature_names_out())
df
# Out:
#    2months  in  learn  love  nlp  will
# 0        1   1      1     1    2     1

# %%
text = 'I am learning Nlp'

# %%
import nltk
nltk.download('punkt_tab')
# !pip install textbolb
from textblob import TextBlob
TextBlob(text).ngrams(1)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ERROR: Could not find a version that satisfies the requirement textbolb (from versions: none)
# ERROR: No matching distribution found for textbolb
# [WordList(['I']), WordList(['am']), WordList(['learning']), WordList(['Nlp'])]

# %%
TextBlob(text).ngrams(2)
# Out:
# [WordList(['I', 'am']),
#  WordList(['am', 'learning']),
#  WordList(['learning', 'Nlp'])]

# %%
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import pickle
from sklearn.linear_model import LogisticRegressionCV
import re
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('covid_fake.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label
# 0  coronavirusmedicalkit.com  Fake
# 1               RudyGiuliani  Fake
# 2                CharlieKirk  Fake
# 3    JoanneWrightForCongress  Fake
# 4    JoanneWrightForCongress  Fake

# %%
df.shape
# Out:
# (1164, 4)

# %%
df['label'].value_counts()
# Out:
# label
# TRUE    584
# Fake    345
# fake    230
# Name: count, dtype: int64

# %%
df.loc[5:15]
# Out:
#                                                 title  \
# 5   CORONA UNMASKED: Chinese Intelligence Officer ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Basic protective measures against the new coro...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Exposing yourself to the sun or to temperature...
# 15  You can recover from the coronavirus disease (...
#
#                                                  text  \
# 5                                                 NaN
# 6   Urgent: Health Bulletin to the Public. Ministr...
# 7   Pls tell ur families, relatives and friendsMOH...
# 8   SERIOUS EXCELLENT ADVICE by Japanese doctors t...
# 9   Stay aware of the latest information on the CO...
# 10  The new Coronavirus may not show signs of infe...
# 11  A vaccine meant for cattle can be used to figh...
# 12  Using a hair dryer to breathe in hot air can c...
# 13  Corona virus before it reaches the lungs it re...
# 14  You can catch COVID-19, no matter how sunny or...
# 15  Most of the people who catch COVID-19 can reco...
#
#                                                source label
# 5                                                 NaN   NaN
# 6                                  Ministry of Health  Fake
# 7                                              NWLLAB  Fake
# 8            Japanese doctors treating COVID-19 cases  Fake
# 9   https://www.who.int/emergencies/diseases/novel...  TRUE
# 10                                     Taiwan Experts  Fake
# 11                                           facebook  Fake
# 12                                            Youtube  Fake
# 13                                            twitter  Fake
# 14  https://www.who.int/emergencies/diseases/novel...  TRUE
# 15  https://www.who.int/emergencies/diseases/novel...   NaN

# %%
df.isna().sum()
# Out:
# title     82
# text      10
# source    20
# label      5
# dtype: int64

# %%
df.loc[df['label'] == 'Fake', ['label']] == 'FAKE'
df.loc[df['label'] == 'Fake', ['label']] == 'FAKE'
df.loc[df['source'] == 'Facebook', ['source']] == 'Facebook'
df.text.fillna(df.title, inplace=True)

df.loc[5]['label'] = "FAKE"
df.loc[15]['label'] = "TRUE"
df.loc[43]['label'] = "FAKE"
df.loc[131]['label'] = "TRUE"
df.loc[5]['label'] = "FAKE"

df.title.fillna('missing', inplace=True)
df.source.fillna('missing', inplace=True)
df['title_text'] = df['title'] + ' ' + df['text']

# %%
df['label'].value_counts()
# Out:
# label
# TRUE    586
# Fake    345
# fake    230
# FAKE      2
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1164, 5)

# %%
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                            missing
# 2                                            missing
# 3                                            missing
# 4                                            missing
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label  \
# 0  coronavirusmedicalkit.com  Fake
# 1               RudyGiuliani  Fake
# 2                CharlieKirk  Fake
# 3    JoanneWrightForCongress  Fake
# 4    JoanneWrightForCongress  Fake
#
#                                           title_text
# 0  Due to the recent outbreak for the Coronavirus...
# 1  missing Hydroxychloroquine has been shown to h...
# 2  missing Fact: Hydroxychloroquine has been show...
# 3  missing The Corona virus is a man made virus c...
# 4  missing Doesn’t @BillGates finance research at...

# %%
df.isna().sum()
# Out:
# title         0
# text          0
# source        0
# label         1
# title_text    0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# TRUE    586
# Fake    345
# fake    230
# FAKE      2
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1164, 5)

# %%
df.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                            missing
# 2                                            missing
# 3                                            missing
# 4                                            missing
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label  \
# 0  coronavirusmedicalkit.com  Fake
# 1               RudyGiuliani  Fake
# 2                CharlieKirk  Fake
# 3    JoanneWrightForCongress  Fake
# 4    JoanneWrightForCongress  Fake
#
#                                           title_text
# 0  Due to the recent outbreak for the Coronavirus...
# 1  missing Hydroxychloroquine has been shown to h...
# 2  missing Fact: Hydroxychloroquine has been show...
# 3  missing The Corona virus is a man made virus c...
# 4  missing Doesn’t @BillGates finance research at...

# %%
df['title_text'][3]
# Out:
# 'missing The Corona virus is a man made virus created in a Wuhan laboratory. Ask @BillGates who financed it.'

# %%
def preprocessor(text):
    text = re.sub('<[^>]*>', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'[\n]', '', text)
    text = text.lower()
    return text
df['title_text'] = df['title_text'].apply(preprocessor)
df['title_text'][3]
# Out:
# 'missing the corona virus is a man made virus created in a wuhan laboratory ask billgates who financed it'

# %%
porter = PorterStemmer()
def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]

# %%
tfidf=TfidfVectorizer(strip_accents=None,
                      lowercase=False,
                      preprocessor=None,
                      tokenizer=tokenizer_porter,
                      use_idf=True,
                      norm='l2',
                      smooth_idf=True)
X=tfidf.fit_transform(df['title_text'])
y=df.label.values

# %%
X.shape
# Out:
# (1164, 27020)

# %%
TfidfVectorizer?

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, \
                                                   test_size=0.3, shuffle=False)

# %%
clf = LogisticRegressionCV(cv=5, scoring='accuracy', random_state=0, n_jobs=-1, \
                          verbose=0, max_iter=300)
clf.fit(X_train, y_train)


fake_news_model = open('fake_news_model.sav', 'wb')
pickle.dump(clf, fake_news_model)
fake_news_model.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-206d4034836a> in <cell line: 0>()
#      28 clf = LogisticRegressionCV(cv=5, scoring='accuracy', random_state=0, n_jobs=-1, \
#      29                           verbose=0, max_iter=300)
# ---> 30 clf.fit(X_train, y_train)
#      31
#      32 # ... (rest of your code) ...
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight, **params)
#    1955
#    1956         if n_classes < 2:
# -> 1957             raise ValueError(
#    1958                 "This solver needs samples of at least 2 classes"
#    1959                 " in the data, but the data contains only one"
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 'missing'

# %%
filename = 'fake_news_model.sav'
saved_clf = pickle.load(open(filename, 'rb'))

saved_clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-cb3792c256e0> in <cell line: 0>()
#       1 filename = 'fake_news_model.sav'
# ----> 2 saved_clf = pickle.load(open(filename, 'rb'))
#       3
#       4 saved_clf.score(X_test, y_test)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fake_news_model.sav'
